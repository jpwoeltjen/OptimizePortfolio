# %% [markdown]
# # Portfolio Optimization

# %%
import numpy as np
import pandas as pd 
from scipy.linalg import eigh, cholesky
from scipy.stats import norm
from matplotlib import pyplot as plt 
plt.style.use('seaborn')
from src import optimize
from src.portfolio import Portfolio



def gen_industry_stocks(n_stocks, market, industry, industry_name, sigma_noise, p_year=250):
    mu = pd.Series(np.random.uniform(low=-0.2, high=0.2, size=n_stocks))/p_year
    beta_market = pd.Series(np.random.uniform(low=0.5, high=2.0, size=n_stocks))
    beta_industry = pd.Series(np.random.uniform(low=0.5, high=2.0, size=n_stocks))
    stocks = pd.DataFrame()

    for i in range(n_stocks):
        stocks[f'{industry_name}_stock_{i}'] = mu[i] + beta_market[i]*market + beta_industry[i]*industry + norm.rvs(size=(1, num_samples))[0]*sigma_noise
    mu.index = stocks.columns
    return stocks, mu, beta_market, beta_industry

def information_ratio(equity_curve, p_year=250):
    return equity_curve.mean()/equity_curve.std()*p_year**0.5



p_year = 250
num_samples = p_year*4

sigma_market = 0.1/p_year**0.5
sigma_banks = 0.1/p_year**0.5
sigma_oil = 0.14/p_year**0.5
sigma_insurance = 0.07/p_year**0.5
sigma_tech = 0.2/p_year**0.5
sigma_bio = 0.12/p_year**0.5
sigma_pharma = 0.22/p_year**0.5
sigma_auto = 0.05/p_year**0.5
sigma_retail = 0.125/p_year**0.5
sigma_manufacturing = 0.1/p_year**0.5

sigma_noise = 0.1/p_year**0.5

# %% [markdown]
# Let's simulate a bunch of stocks belonging to different industries. Each stock is composed of a deterministic trend $\mu$, a loading on the market related stochastic trend $\beta_{market}$ and a loading on the industry specific stochastic trend $\beta_{industry}$. For each stock, $\mu$, $\beta_{market}$, and $\beta_{industry}$ are sampled from a uniform distribution. In the first simulation, I compare a mean-variance optimization with a naive diversification approch where each asset is equally weighted with sign of the expected value. At this point I should emphasize that I assume perfect knowledge of the expected value. Traditionally, the expected value is estimated by the in-sample first moment of the asset. In my example, this would actually make sense since the mean is a consistent estimator of the deterministic trend. In practive, howerver, there is probably not a constant deterministic trend. This is where the alpha model steps in, which is not the topic of this study and thus assumed given.

# %%
def plot_equity_curve(log_returns):
    plt.plot(np.exp(log_returns.cumsum()))
    plt.title('Equity Curve')
    plt.xlabel('Period')
    plt.ylabel('Equity Value')
    plt.show()



def show_standard_optimized_equity(n_stocks, industry):
    trainig_pct = 0.5
    n_train = int(trainig_pct*num_samples)
    market = norm.rvs(size=(1, num_samples))[0]*sigma_market
    industries = {}
    
    stocks, mu, beta_market, beta_industry = gen_industry_stocks(n_stocks, market, list(industry.values())[0], list(industry.keys())[0], sigma_noise, p_year)
    plot_equity_curve(stocks)
    weights = optimize.minimize_objective(mu.index,
                                     optimize.negative_sharpe,
                                     True,
                                     (-1, 1),
                                     mu, stocks[:n_train].cov(),
                                     0.0, 0.0,)

    portfolio_sm_is = np.dot(stocks.values,np.array(list(weights.values())))[:n_train]
    IR_ann = information_ratio(portfolio_sm_is)
    print('IR sm_is', IR_ann )
    plot_equity_curve(portfolio_sm_is)
    
    portfolio_equal_is = np.dot(stocks.values,mu.apply(np.sign)/mu.shape[0])[:n_train]
    IR_ann = information_ratio(portfolio_equal_is)
    print('IR equal_is', IR_ann )
    plot_equity_curve(portfolio_equal_is)

    portfolio_sm_oos = np.dot(stocks.values,np.array(list(weights.values())))[n_train:]
    IR_ann = information_ratio(portfolio_sm_oos)
    print('IR sm_oos', IR_ann )
    plot_equity_curve(portfolio_sm_oos)
    
    portfolio_equal_oos = np.dot(stocks.values,mu.apply(np.sign)/mu.shape[0])[:n_train]
    IR_ann = information_ratio(portfolio_equal_oos)
    print('IR equal_is', IR_ann )
    plot_equity_curve(portfolio_equal_oos)
    
    return weights

# %% [markdown]
# The results below show that out of sample performance is decent if the number of assets is relatively small. It definently beats equal weighting.

# %%
industry = {}
industry['manufacturing'] = norm.rvs(size=(1, num_samples))[0]*sigma_manufacturing
show_standard_optimized_equity(n_stocks=100, industry=industry)
# Out:
# IR sm_is 12.207226035811694
# IR equal_is 5.539038210487922
# IR sm_oos 9.905120095965634
# IR equal_is 5.539038210487922
# {'manufacturing_stock_0': 0.07260595999808171,
#  'manufacturing_stock_1': -0.08268462875290276,
#  'manufacturing_stock_10': -0.08927931885529698,
#  'manufacturing_stock_11': -0.06246399479941414,
#  'manufacturing_stock_12': -0.09019921661960295,
#  'manufacturing_stock_13': 0.05108069754263801,
#  'manufacturing_stock_14': -0.014962901810652582,
#  'manufacturing_stock_15': -0.07207687162271076,
#  'manufacturing_stock_16': -0.11198449371000098,
#  'manufacturing_stock_17': -0.11015829793627256,
#  'manufacturing_stock_18': 0.07707010780582631,
#  'manufacturing_stock_19': -0.01129905519000523,
#  'manufacturing_stock_2': 0.015449060578023893,
#  'manufacturing_stock_20': -0.07453720084724468,
#  'manufacturing_stock_21': -0.06436915868456336,
#  'manufacturing_stock_22': 0.02877068184752479,
#  'manufacturing_stock_23': 0.05151833387652114,
#  'manufacturing_stock_24': 0.02092787348390043,
#  'manufacturing_stock_25': 0.015140095983077686,
#  'manufacturing_stock_26': 0.11552159215126707,
#  'manufacturing_stock_27': 0.10993537602298786,
#  'manufacturing_stock_28': 0.026623798050915103,
#  'manufacturing_stock_29': 0.001816864466111631,
#  'manufacturing_stock_3': 0.0010985763579707192,
#  'manufacturing_stock_30': 0.06672393155726054,
#  'manufacturing_stock_31': 0.0691877453567465,
#  'manufacturing_stock_32': -0.010167743961443966,
#  'manufacturing_stock_33': -0.1278481280770606,
#  'manufacturing_stock_34': -0.05946728877574119,
#  'manufacturing_stock_35': 0.04759878606776197,
#  'manufacturing_stock_36': 0.07037897892893259,
#  'manufacturing_stock_37': 0.05450144081247834,
#  'manufacturing_stock_38': 0.08490270083851631,
#  'manufacturing_stock_39': -0.11232087430864725,
#  'manufacturing_stock_4': 0.058617016835494404,
#  'manufacturing_stock_40': -0.0909508498688569,
#  'manufacturing_stock_41': -0.08181172757424768,
#  'manufacturing_stock_42': -0.053029333623592544,
#  'manufacturing_stock_43': -0.06354972319598783,
#  'manufacturing_stock_44': -0.0056277012446609995,
#  'manufacturing_stock_45': -0.07763123384905792,
#  'manufacturing_stock_46': 0.040649439829188304,
#  'manufacturing_stock_47': -0.029283117330267464,
#  'manufacturing_stock_48': 0.04148132560540792,
#  'manufacturing_stock_49': 0.10383853604492584,
#  'manufacturing_stock_5': -0.09737007026334209,
#  'manufacturing_stock_50': -0.05330066743332452,
#  'manufacturing_stock_51': -0.07601664313706523,
#  'manufacturing_stock_52': 0.08871580084145213,
#  'manufacturing_stock_53': -0.029589796067724005,
#  'manufacturing_stock_54': -0.009214974699785434,
#  'manufacturing_stock_55': 0.06145121170401037,
#  'manufacturing_stock_56': 0.10326562662007958,
#  'manufacturing_stock_57': 0.008655399854590741,
#  'manufacturing_stock_58': -0.03905302087930443,
#  'manufacturing_stock_59': -0.05834388975309926,
#  'manufacturing_stock_6': 0.10302798028927364,
#  'manufacturing_stock_60': -0.04277989897672065,
#  'manufacturing_stock_61': 0.06619452093406239,
#  'manufacturing_stock_62': -0.13012462636198915,
#  'manufacturing_stock_63': 0.1508719060854004,
#  'manufacturing_stock_64': 0.08622449624432627,
#  'manufacturing_stock_65': -0.1350319929005005,
#  'manufacturing_stock_66': -0.040116061033773534,
#  'manufacturing_stock_67': -0.048527752948233346,
#  'manufacturing_stock_68': 0.07002987617081965,
#  'manufacturing_stock_69': 0.14884514811630403,
#  'manufacturing_stock_7': -0.04328503323968375,
#  'manufacturing_stock_70': 0.13316773875401108,
#  'manufacturing_stock_71': 0.03352707071217485,
#  'manufacturing_stock_72': 0.13117234785014473,
#  'manufacturing_stock_73': -0.1582311457386619,
#  'manufacturing_stock_74': -0.02245130704373145,
#  'manufacturing_stock_75': 0.13260132662155913,
#  'manufacturing_stock_76': 0.06919204494331993,
#  'manufacturing_stock_77': -0.07963103578634918,
#  'manufacturing_stock_78': 0.15966754502853162,
#  'manufacturing_stock_79': -0.06651856565537231,
#  'manufacturing_stock_8': 0.0026977277622807975,
#  'manufacturing_stock_80': -0.18327123323058744,
#  'manufacturing_stock_81': 0.09932663401482429,
#  'manufacturing_stock_82': 0.03519127183457526,
#  'manufacturing_stock_83': 0.0798696817391402,
#  'manufacturing_stock_84': 0.03917535068425021,
#  'manufacturing_stock_85': -0.06330514730755192,
#  'manufacturing_stock_86': -0.005541105305068297,
#  'manufacturing_stock_87': -0.11974588735774185,
#  'manufacturing_stock_88': -0.02077176840850308,
#  'manufacturing_stock_89': -0.004383884236498372,
#  'manufacturing_stock_9': -0.021808105144573393,
#  'manufacturing_stock_90': 0.047741510865438985,
#  'manufacturing_stock_91': -0.0659251337838938,
#  'manufacturing_stock_92': -0.10345295847883246,
#  'manufacturing_stock_93': -0.01095798427372175,
#  'manufacturing_stock_94': -0.14974353342955274,
#  'manufacturing_stock_95': 0.11446366155840977,
#  'manufacturing_stock_96': 0.09420505219550385,
#  'manufacturing_stock_97': 0.031231575094196877,
#  'manufacturing_stock_98': 0.035462508065763676,
#  'manufacturing_stock_99': 0.022782148887413686}

# %% [markdown]
# When the number of assets is relatively large, however, the out-of-sample performance is significantly smaller than the in-sample performance as demonstrated by the information ratio (IR). Even the very naive approach of equal weighting beats mean-variance optimization out-of-sample embarrassingly often.

# %%
weights = show_standard_optimized_equity(n_stocks=300, industry=industry)
# Out:
# IR sm_is 31.206177128002754
# IR equal_is 10.601045346167497
# IR sm_oos 11.740593751760835
# IR equal_is 10.601045346167497

# %%
pf = Portfolio(assets=weights.keys(), position=pd.Series(weights), price=[1]*len(weights.keys()))
print(pf)
print('largest long:', pf[0], pf.position(pf[0]))
print('largest short:', pf[-1], pf.position(pf[-1]))
# Out:
# Portfolio: 300 Assets, $34.69 Long, $34.69 Short
# largest long: manufacturing_stock_15 0.8597610376780905
# largest short: manufacturing_stock_272 -0.6799587450644163

# %%
pf.portfolio_df.head()
# Out:
#                          position  price  factor_value  sector_id  \
# manufacturing_stock_15   0.859761      1           1.0        0.0
# manufacturing_stock_4    0.755014      1           1.0        0.0
# manufacturing_stock_297  0.741496      1           1.0        0.0
# manufacturing_stock_110  0.630224      1           1.0        0.0
# manufacturing_stock_102  0.617315      1           1.0        0.0
#
#                          position_value
# manufacturing_stock_15         0.859761
# manufacturing_stock_4          0.755014
# manufacturing_stock_297        0.741496
# manufacturing_stock_110        0.630224
# manufacturing_stock_102        0.617315

# %%
pf.portfolio_df.position_value.plot(style='.')
plt.title('Position Allocation')
plt.xlabel('Ordered Positions')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Here you can see a typical result of mean-variance optimization. There are some very large positions. These are most likely due to estimation errors of the covariance matrix and thus undesirable. This problem is even greater when $\mu$, too, is estimated with error. As the number of assets grows, there is a higher likelihood of observing a extreme covariance value by chance and thus this problem actually grows with the number of assets. This is so common that it has a name. In the literature it goes by 'Error Maximization'.

# %% [markdown]
# ## Imposing Structure
#
# To reduce Error Maximization we need to impose structure. One way to do this is by using our knowledge that stocks usually cluster (e.g., into certain industries). It seems like a good idea to encode this prior knowledge by mean-variance optimize stocks within clusters and then optimize allocation to these clusters. This is persued next and compared to the standard optimization.

# %%
trainig_pct = 0.5
n_train = int(trainig_pct*num_samples)
ir_sm_is = []
ir_sm_oos = []
ir_hier_is = []
ir_hier_oos = []
n_stocks = 30

for j in range(10):
    print('MC run: ', j)
    
    market = norm.rvs(size=(1, num_samples))[0]*sigma_market
    industries = {}
    industries['banks'] =  norm.rvs(size=(1, num_samples))[0]*sigma_banks
    industries['oil'] = norm.rvs(size=(1, num_samples))[0]*sigma_oil
    industries['insurance'] = norm.rvs(size=(1, num_samples))[0]*sigma_insurance
    industries['tech'] = norm.rvs(size=(1, num_samples))[0]*sigma_tech
    industries['bio'] = norm.rvs(size=(1, num_samples))[0]*sigma_bio
    industries['pharma'] = norm.rvs(size=(1, num_samples))[0]*sigma_pharma
    industries['auto'] = norm.rvs(size=(1, num_samples))[0]*sigma_auto
    industries['retail'] = norm.rvs(size=(1, num_samples))[0]*sigma_retail
    
    industries_stocks = {}
    industries_mu = {}
    industries_beta_market = {}
    industries_beta_industries = {}
    industries_weights = {}
    industries_portfolio = {}

    stocks_all = pd.DataFrame()
    expected_returns_all = pd.Series()

    for i in industries.keys():
        industries_stocks[i], industries_mu[i], industries_beta_market[i], industries_beta_industries[i] = gen_industry_stocks(n_stocks, market, industries[i], i, sigma_noise, p_year)
        stocks_all = pd.concat([stocks_all,industries_stocks[i]], axis=1)
        expected_returns_all = expected_returns_all.append(industries_mu[i])

        industries_weights[i] = optimize.minimize_objective(industries_mu[i].index,
                                     optimize.negative_sharpe,
                                     True,
                                     (-1, 1),
                                     industries_mu[i], industries_stocks[i][:n_train].cov(),
                                     0.0, 0.0,)
        industries_portfolio[i] = np.dot(industries_stocks[i].values,np.array(list(industries_weights[i].values())))


    #standard sample moments
    weights = optimize.minimize_objective(expected_returns_all.index,
                                     optimize.negative_sharpe,
                                     True,
                                     (-1, 1),
                                     expected_returns_all, stocks_all[:n_train].cov(),
                                     0.0, 0.0,)
    portfolio_sm_is = np.dot(stocks_all.values,np.array(list(weights.values())))[:n_train]
    IR_ann = information_ratio(portfolio_sm_is)
    ir_sm_is.append(IR_ann)
    print('IR sm_is', IR_ann )

    portfolio_sm_oos = np.dot(stocks_all.values,np.array(list(weights.values())))[n_train:]
    IR_ann = information_ratio(portfolio_sm_oos)
    ir_sm_oos.append(IR_ann)
    print('IR sm_oos', IR_ann )

    # hierarchical
    # optimize allocation to industry
    industry_weights = optimize.minimize_objective(industries.keys(),
                                     optimize.negative_sharpe,
                                     False,
                                     (-1, 1),
                                     pd.Series(index=industries.keys(), data=[0.1]*len(industries.keys())),
                                     pd.DataFrame(industries_portfolio).cov()[:n_train]*100000,
                                     0.0, 0.0,)
#     # equal weighting industries
#     for i in industry_weights.keys():
#         industry_weights[i] = 1/len(industries)

    print(industry_weights)
    portfolio_hier_is = np.dot(pd.DataFrame(industries_portfolio).values,
                            np.array(list(industry_weights.values())))[:n_train]

    IR_ann = information_ratio(portfolio_hier_is)
    print('IR hier is', IR_ann )
    ir_hier_is.append(IR_ann)

    portfolio_hier_oos = np.dot(pd.DataFrame(industries_portfolio).values,
                            np.array(list(industry_weights.values())))[n_train:]

    IR_ann = information_ratio(portfolio_hier_oos)
    print('IR hier oos', IR_ann )
    ir_hier_oos.append(IR_ann)
# Out:
# MC run:  0
# IR sm_is 25.181436599369572
# IR sm_oos 11.90498566907935
# {'banks': 0.1626676439770934, 'oil': 0.14007962107165622, 'insurance': 0.1218150842144324, 'tech': 0.2520634385690276, 'bio': 0.13178569508547008, 'pharma': 0.03729191111037741, 'auto': 0.03575258051231598, 'retail': 0.11854402545962689}
# IR hier is 16.60278321878579
# IR hier oos 16.637342575556058
# MC run:  1
# IR sm_is 22.806299670588544
# IR sm_oos 14.891802989982843
# {'banks': 0.20277754017418256, 'oil': 0.05377025811690404, 'insurance': 0.0528072703670995, 'tech': 0.039275103584010915, 'bio': 0.16525336457378714, 'pharma': 0.4108313072302225, 'auto': 0.019383053365127204, 'retail': 0.05590210258866617}
# IR hier is 15.550304816187337
# IR hier oos 17.02363086748163
# MC run:  2
# IR sm_is 25.23918488330303
# IR sm_oos 11.719425020177626
# {'banks': 0.06521500197274396, 'oil': 0.14218449605857483, 'insurance': 0.04565352528710967, 'tech': 0.23878911524078988, 'bio': 0.13694970430373116, 'pharma': 0.1998229375922704, 'auto': 0.05411676923261395, 'retail': 0.11726845031216616}
# IR hier is 19.460272496863414
# IR hier oos 15.207754766001166
# MC run:  3
# IR sm_is 24.644810414140935
# IR sm_oos 11.47842414566046
# {'banks': 0.18306734163169533, 'oil': 0.05403013781312442, 'insurance': 0.09966293279690733, 'tech': 0.3189694643628712, 'bio': 0.05354867845664054, 'pharma': 0.11462629429998915, 'auto': 0.0550092756461655, 'retail': 0.12108587499260658}
# IR hier is 16.26472365300683
# IR hier oos 15.168175773340263
# MC run:  4
# IR sm_is 24.41197807113876
# IR sm_oos 13.88246808074267
# {'banks': 0.2201713080958537, 'oil': 0.01911232261611247, 'insurance': 0.09837823839712845, 'tech': 0.04783389417843963, 'bio': 0.24802633814582836, 'pharma': 0.25907092692686323, 'auto': 0.0664684167853474, 'retail': 0.04093855485442688}
# IR hier is 15.428876733441514
# IR hier oos 17.021981059798946
# MC run:  5
# IR sm_is 23.416325134335008
# IR sm_oos 12.32808525982886
# {'banks': 0.04209739154255993, 'oil': 0.06032473248373356, 'insurance': 0.05938158667513378, 'tech': 0.20033024219910384, 'bio': 0.03854191662251316, 'pharma': 0.39197286654403724, 'auto': 0.07552400469514513, 'retail': 0.13182725923777344}
# IR hier is 15.670462376564261
# IR hier oos 15.307448505676751
# MC run:  6
# IR sm_is 22.026351412844992
# IR sm_oos 12.129078805375066
# {'banks': 0.13389282686705695, 'oil': 0.2830654039515242, 'insurance': 0.07883536051184326, 'tech': 0.3807235827732005, 'bio': 0.03369186433685145, 'pharma': 0.004181489454647383, 'auto': 0.07517280915529402, 'retail': 0.010436662949582365}
# IR hier is 13.40199723276573
# IR hier oos 13.501063215004715
# MC run:  7
# IR sm_is 24.006610260483072
# IR sm_oos 11.67319270665437
# {'banks': 0.03493772767654533, 'oil': 0.040420421472447385, 'insurance': 0.02341629701594347, 'tech': 0.39473441579407426, 'bio': 0.08071265127609546, 'pharma': 0.07259022987083731, 'auto': 0.08101186650353734, 'retail': 0.2721763903905195}
# IR hier is 16.45141720146724
# IR hier oos 13.993265289984368
# MC run:  8
# IR sm_is 25.621580285910998
# IR sm_oos 14.248526636629762
# {'banks': 0.12058091220564048, 'oil': 0.3455295414412452, 'insurance': 0.09676162377775703, 'tech': 0.06609299697017297, 'bio': 0.22691433583125187, 'pharma': 0.07802149877683986, 'auto': 0.05349792505284668, 'retail': 0.012601165944245894}
# IR hier is 17.891822979480935
# IR hier oos 16.615228885428202
# MC run:  9
# IR sm_is 26.779890741036404
# IR sm_oos 11.103216871933887
# {'banks': 0.13796034317232672, 'oil': 0.028849327680179053, 'insurance': 0.15517389887169625, 'tech': 0.10634399596370564, 'bio': 0.06439756706535824, 'pharma': 0.10850518019368764, 'auto': 0.016316753809358417, 'retail': 0.3824529332436882}
# IR hier is 16.678986530707995
# IR hier oos 14.784582916327466

# %%
data_a = [ir_sm_is, ir_hier_is]
data_b = [ir_sm_oos, ir_hier_oos]

ticks = ['Markowitz', 'Hierarchical']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0-0.4, sym='', widths=0.6)
bpr = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0+0.4, sym='', widths=0.6)

set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='IS')
plt.plot([], c='#2C7BB6', label='OOS')
plt.legend()
plt.title('Markowitz vs. Hierarchical ')
plt.ylabel('Information Ratio')
plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
# plt.ylim(0, 8)
plt.tight_layout()
# plt.savefig('boxcompare.png')

# %%
performance_factor = np.mean(ir_hier_oos)/np.mean(ir_sm_oos)
print('OOS performance gain factor', performance_factor)
# Out:
# OOS performance gain factor 1.2385247049518933

# %%
Portfolio?
dir(Portfolio)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'from_dataframe',
#  'gross_exposure',
#  'long_exposure',
#  'long_exposure_pct',
#  'longs',
#  'net_exposure',
#  'position',
#  'sector_net_exposures',
#  'short_exposure',
#  'short_exposure_pct',
#  'shorts',
#  'trade']

# %%
pf = Portfolio(assets=weights.keys(),
               position=pd.Series(weights),
               price=[1]*len(weights.keys()),
               sector_id=pd.Series(list(weights.keys())).str[:3].values
              )
print(pf)
print('largest long:', pf[0], pf.position(pf[0]))
print('largest short:', pf[-1], pf.position(pf[-1]))
pf.sector_net_exposures()
# Out:
# Portfolio: 240 Assets, $33.29 Long, $33.29 Short
# largest long: insurance_stock_21 1.0
# largest short: auto_stock_4 -0.8025638205071502
#            position_value
# sector_id
# aut             -0.893298
# ban             -0.442827
# bio              0.378727
# ins              0.780305
# oil              0.035580
# pha             -0.503033
# ret              0.200602
# tec              0.443945

# %%
pf.portfolio_df
# Out:
#                     position  price  factor_value sector_id  position_value
# insurance_stock_21  1.000000      1           1.0       ins        1.000000
# retail_stock_8      0.995950      1           1.0       ret        0.995950
# auto_stock_15       0.820532      1           1.0       aut        0.820532
# auto_stock_7        0.746446      1           1.0       aut        0.746446
# banks_stock_16      0.697311      1           1.0       ban        0.697311
# tech_stock_1        0.686416      1           1.0       tec        0.686416
# bio_stock_21        0.682185      1           1.0       bio        0.682185
# banks_stock_19      0.661479      1           1.0       ban        0.661479
# oil_stock_27        0.620315      1           1.0       oil        0.620315
# tech_stock_10       0.601746      1           1.0       tec        0.601746
# insurance_stock_1   0.597590      1           1.0       ins        0.597590
# banks_stock_25      0.595127      1           1.0       ban        0.595127
# insurance_stock_20  0.573362      1           1.0       ins        0.573362
# banks_stock_2       0.545424      1           1.0       ban        0.545424
# oil_stock_28        0.533698      1           1.0       oil        0.533698
# oil_stock_0         0.529999      1           1.0       oil        0.529999
# tech_stock_29       0.518783      1           1.0       tec        0.518783
# oil_stock_7         0.513351      1           1.0       oil        0.513351
# retail_stock_9      0.503784      1           1.0       ret        0.503784
# oil_stock_10        0.501268      1           1.0       oil        0.501268
# auto_stock_6        0.456781      1           1.0       aut        0.456781
# bio_stock_27        0.430508      1           1.0       bio        0.430508
# bio_stock_6         0.429178      1           1.0       bio        0.429178
# banks_stock_12      0.426321      1           1.0       ban        0.426321
# retail_stock_13     0.423597      1           1.0       ret        0.423597
# insurance_stock_9   0.419126      1           1.0       ins        0.419126
# retail_stock_26     0.416471      1           1.0       ret        0.416471
# pharma_stock_28     0.416295      1           1.0       pha        0.416295
# banks_stock_7       0.414534      1           1.0       ban        0.414534
# bio_stock_24        0.400090      1           1.0       bio        0.400090
# ...                      ...    ...           ...       ...             ...
# banks_stock_5      -0.437679      1           1.0       ban       -0.437679
# pharma_stock_6     -0.439570      1           1.0       pha       -0.439570
# insurance_stock_14 -0.447840      1           1.0       ins       -0.447840
# auto_stock_29      -0.456238      1           1.0       aut       -0.456238
# retail_stock_27    -0.458751      1           1.0       ret       -0.458751
# banks_stock_26     -0.459913      1           1.0       ban       -0.459913
# oil_stock_21       -0.468705      1           1.0       oil       -0.468705
# tech_stock_20      -0.472752      1           1.0       tec       -0.472752
# auto_stock_5       -0.473048      1           1.0       aut       -0.473048
# bio_stock_15       -0.476319      1           1.0       bio       -0.476319
# tech_stock_26      -0.479426      1           1.0       tec       -0.479426
# oil_stock_25       -0.493983      1           1.0       oil       -0.493983
# auto_stock_27      -0.518638      1           1.0       aut       -0.518638
# banks_stock_11     -0.523122      1           1.0       ban       -0.523122
# oil_stock_17       -0.536375      1           1.0       oil       -0.536375
# bio_stock_28       -0.542761      1           1.0       bio       -0.542761
# banks_stock_27     -0.544708      1           1.0       ban       -0.544708
# oil_stock_13       -0.553082      1           1.0       oil       -0.553082
# pharma_stock_18    -0.562960      1           1.0       pha       -0.562960
# bio_stock_10       -0.597750      1           1.0       bio       -0.597750
# bio_stock_8        -0.601259      1           1.0       bio       -0.601259
# insurance_stock_8  -0.603298      1           1.0       ins       -0.603298
# pharma_stock_13    -0.607924      1           1.0       pha       -0.607924
# insurance_stock_0  -0.622857      1           1.0       ins       -0.622857
# pharma_stock_19    -0.624846      1           1.0       pha       -0.624846
# tech_stock_9       -0.630280      1           1.0       tec       -0.630280
# insurance_stock_28 -0.631864      1           1.0       ins       -0.631864
# retail_stock_3     -0.689095      1           1.0       ret       -0.689095
# oil_stock_8        -0.692094      1           1.0       oil       -0.692094
# auto_stock_4       -0.802564      1           1.0       aut       -0.802564
#
# [240 rows x 5 columns]

# %%
pf.portfolio_df.position_value.plot(style='.')

# %% [markdown]
# Here you can see a typical result of mean-variance optimization. There are some very large positions. These are most likely due to estimation errors of the covariance matrix and thus undesirable. This problem is even greater when $\mu$, too, is estimated with error. As the number of assets grows, there is a higher likelihood of observing a extreme covariance value by chance and thus this problem actually grows with the number of assets. This is so common that it has a name. In the literature it goes by 'Error Maximization'.

# %%
# pd.Series(index=industries.keys(), data=[0.1]*len(industries.keys()))
pd.DataFrame(industries_portfolio).cov()*100000
# Out:
#               banks       oil  insurance      tech       bio    pharma  \
# banks      0.530098  0.087906  -0.022538  0.005253 -0.000520 -0.008839
# oil        0.087906  2.101895  -0.026041  0.037814 -0.028558  0.030396
# insurance -0.022538 -0.026041   0.471763  0.000822  0.006008  0.000370
# tech       0.005253  0.037814   0.000822  0.600347 -0.004087 -0.000859
# bio       -0.000520 -0.028558   0.006008 -0.004087  0.949222  0.027930
# pharma    -0.008839  0.030396   0.000370 -0.000859  0.027930  0.598825
# auto       0.058122  0.012729  -0.008034  0.012622 -0.020096 -0.017566
# retail    -0.007990 -0.012611  -0.000681  0.010230  0.015819  0.008958
#
#                auto    retail
# banks      0.058122 -0.007990
# oil        0.012729 -0.012611
# insurance -0.008034 -0.000681
# tech       0.012622  0.010230
# bio       -0.020096  0.015819
# pharma    -0.017566  0.008958
# auto       3.740187  0.008797
# retail     0.008797  0.177495

# %%
industries_mu
# Out:
# {'auto': auto_stock_0    -0.000584
#  auto_stock_1     0.000332
#  auto_stock_2    -0.000285
#  auto_stock_3     0.000390
#  auto_stock_4    -0.000560
#  auto_stock_5    -0.000567
#  auto_stock_6     0.000678
#  auto_stock_7     0.000323
#  auto_stock_8     0.000264
#  auto_stock_9    -0.000360
#  auto_stock_10   -0.000728
#  auto_stock_11    0.000472
#  auto_stock_12    0.000666
#  auto_stock_13    0.000767
#  auto_stock_14    0.000450
#  auto_stock_15    0.000732
#  auto_stock_16    0.000466
#  auto_stock_17    0.000088
#  auto_stock_18   -0.000069
#  auto_stock_19    0.000114
#  auto_stock_20   -0.000646
#  auto_stock_21    0.000081
#  auto_stock_22    0.000735
#  auto_stock_23   -0.000188
#  auto_stock_24    0.000082
#  auto_stock_25   -0.000013
#  auto_stock_26   -0.000067
#  auto_stock_27    0.000145
#  auto_stock_28   -0.000378
#  auto_stock_29   -0.000787
#  dtype: float64, 'banks': banks_stock_0     0.000613
#  banks_stock_1    -0.000395
#  banks_stock_2     0.000543
#  banks_stock_3     0.000021
#  banks_stock_4     0.000407
#  banks_stock_5    -0.000398
#  banks_stock_6    -0.000476
#  banks_stock_7     0.000565
#  banks_stock_8    -0.000460
#  banks_stock_9    -0.000550
#  banks_stock_10   -0.000343
#  banks_stock_11   -0.000474
#  banks_stock_12   -0.000578
#  banks_stock_13    0.000754
#  banks_stock_14    0.000090
#  banks_stock_15   -0.000509
#  banks_stock_16    0.000783
#  banks_stock_17    0.000127
#  banks_stock_18   -0.000653
#  banks_stock_19    0.000342
#  banks_stock_20   -0.000739
#  banks_stock_21   -0.000461
#  banks_stock_22   -0.000254
#  banks_stock_23   -0.000611
#  banks_stock_24    0.000232
#  banks_stock_25    0.000118
#  banks_stock_26   -0.000211
#  banks_stock_27   -0.000421
#  banks_stock_28   -0.000405
#  banks_stock_29   -0.000748
#  dtype: float64, 'bio': bio_stock_0     0.000173
#  bio_stock_1     0.000426
#  bio_stock_2     0.000624
#  bio_stock_3     0.000449
#  bio_stock_4     0.000438
#  bio_stock_5     0.000538
#  bio_stock_6     0.000449
#  bio_stock_7     0.000140
#  bio_stock_8    -0.000709
#  bio_stock_9    -0.000237
#  bio_stock_10   -0.000471
#  bio_stock_11    0.000226
#  bio_stock_12   -0.000771
#  bio_stock_13    0.000010
#  bio_stock_14    0.000576
#  bio_stock_15   -0.000064
#  bio_stock_16    0.000089
#  bio_stock_17    0.000454
#  bio_stock_18    0.000179
#  bio_stock_19    0.000232
#  bio_stock_20    0.000606
#  bio_stock_21    0.000471
#  bio_stock_22   -0.000029
#  bio_stock_23   -0.000013
#  bio_stock_24    0.000650
#  bio_stock_25    0.000278
#  bio_stock_26    0.000307
#  bio_stock_27    0.000558
#  bio_stock_28   -0.000626
#  bio_stock_29   -0.000785
#  dtype: float64, 'insurance': insurance_stock_0    -0.000788
#  insurance_stock_1     0.000243
#  insurance_stock_2    -0.000401
#  insurance_stock_3    -0.000589
#  insurance_stock_4     0.000142
#  insurance_stock_5     0.000187
#  insurance_stock_6    -0.000556
#  insurance_stock_7     0.000685
#  insurance_stock_8    -0.000495
#  insurance_stock_9     0.000261
#  insurance_stock_10   -0.000340
#  insurance_stock_11    0.000284
#  insurance_stock_12   -0.000130
#  insurance_stock_13    0.000036
#  insurance_stock_14   -0.000693
#  insurance_stock_15    0.000319
#  insurance_stock_16    0.000490
#  insurance_stock_17    0.000316
#  insurance_stock_18   -0.000522
#  insurance_stock_19   -0.000046
#  insurance_stock_20    0.000677
#  insurance_stock_21    0.000783
#  insurance_stock_22   -0.000434
#  insurance_stock_23    0.000025
#  insurance_stock_24   -0.000707
#  insurance_stock_25    0.000302
#  insurance_stock_26   -0.000106
#  insurance_stock_27    0.000312
#  insurance_stock_28    0.000083
#  insurance_stock_29   -0.000313
#  dtype: float64, 'oil': oil_stock_0     0.000416
#  oil_stock_1     0.000313
#  oil_stock_2     0.000220
#  oil_stock_3     0.000548
#  oil_stock_4    -0.000003
#  oil_stock_5    -0.000693
#  oil_stock_6     0.000484
#  oil_stock_7     0.000082
#  oil_stock_8    -0.000541
#  oil_stock_9    -0.000013
#  oil_stock_10    0.000285
#  oil_stock_11    0.000751
#  oil_stock_12    0.000195
#  oil_stock_13   -0.000767
#  oil_stock_14   -0.000171
#  oil_stock_15    0.000287
#  oil_stock_16   -0.000449
#  oil_stock_17   -0.000071
#  oil_stock_18   -0.000102
#  oil_stock_19    0.000018
#  oil_stock_20    0.000594
#  oil_stock_21   -0.000798
#  oil_stock_22   -0.000466
#  oil_stock_23    0.000427
#  oil_stock_24    0.000692
#  oil_stock_25    0.000354
#  oil_stock_26    0.000234
#  oil_stock_27    0.000676
#  oil_stock_28   -0.000181
#  oil_stock_29   -0.000066
#  dtype: float64, 'pharma': pharma_stock_0    -0.000547
#  pharma_stock_1    -0.000035
#  pharma_stock_2     0.000225
#  pharma_stock_3     0.000757
#  pharma_stock_4     0.000618
#  pharma_stock_5     0.000016
#  pharma_stock_6    -0.000623
#  pharma_stock_7    -0.000207
#  pharma_stock_8    -0.000646
#  pharma_stock_9     0.000578
#  pharma_stock_10    0.000228
#  pharma_stock_11   -0.000668
#  pharma_stock_12    0.000418
#  pharma_stock_13   -0.000588
#  pharma_stock_14   -0.000228
#  pharma_stock_15   -0.000342
#  pharma_stock_16    0.000692
#  pharma_stock_17    0.000487
#  pharma_stock_18   -0.000115
#  pharma_stock_19   -0.000366
#  pharma_stock_20   -0.000048
#  pharma_stock_21    0.000145
#  pharma_stock_22    0.000304
#  pharma_stock_23    0.000649
#  pharma_stock_24    0.000652
#  pharma_stock_25   -0.000289
#  pharma_stock_26    0.000730
#  pharma_stock_27    0.000230
#  pharma_stock_28    0.000750
#  pharma_stock_29    0.000054
#  dtype: float64, 'retail': retail_stock_0     0.000225
#  retail_stock_1     0.000142
#  retail_stock_2    -0.000194
#  retail_stock_3    -0.000786
#  retail_stock_4    -0.000458
#  retail_stock_5     0.000451
#  retail_stock_6    -0.000447
#  retail_stock_7    -0.000311
#  retail_stock_8     0.000293
#  retail_stock_9     0.000071
#  retail_stock_10   -0.000517
#  retail_stock_11    0.000302
#  retail_stock_12    0.000615
#  retail_stock_13    0.000415
#  retail_stock_14    0.000391
#  retail_stock_15    0.000404
#  retail_stock_16    0.000051
#  retail_stock_17    0.000179
#  retail_stock_18    0.000126
#  retail_stock_19    0.000624
#  retail_stock_20   -0.000288
#  retail_stock_21    0.000299
#  retail_stock_22   -0.000766
#  retail_stock_23   -0.000640
#  retail_stock_24    0.000578
#  retail_stock_25   -0.000053
#  retail_stock_26    0.000177
#  retail_stock_27   -0.000378
#  retail_stock_28   -0.000436
#  retail_stock_29    0.000485
#  dtype: float64, 'tech': tech_stock_0     0.000659
#  tech_stock_1     0.000510
#  tech_stock_2     0.000273
#  tech_stock_3    -0.000602
#  tech_stock_4    -0.000239
#  tech_stock_5    -0.000648
#  tech_stock_6    -0.000780
#  tech_stock_7     0.000308
#  tech_stock_8     0.000109
#  tech_stock_9    -0.000725
#  tech_stock_10    0.000553
#  tech_stock_11   -0.000407
#  tech_stock_12   -0.000398
#  tech_stock_13    0.000320
#  tech_stock_14   -0.000624
#  tech_stock_15   -0.000638
#  tech_stock_16    0.000079
#  tech_stock_17   -0.000718
#  tech_stock_18   -0.000725
#  tech_stock_19   -0.000026
#  tech_stock_20   -0.000488
#  tech_stock_21    0.000018
#  tech_stock_22    0.000075
#  tech_stock_23   -0.000487
#  tech_stock_24   -0.000745
#  tech_stock_25    0.000062
#  tech_stock_26   -0.000640
#  tech_stock_27   -0.000676
#  tech_stock_28    0.000293
#  tech_stock_29    0.000046
#  dtype: float64}

# %%
np.exp(stocks.cumsum(axis=0)).plot(legend=False)

# %%
stocks.corr()

# %%
covar = stocks.cov()

# %%
# GOD
expected_returns = mu
weights = optimize.minimize_objective(expected_returns.index,
                                 optimize.negative_sharpe,
                                 True,
                                 (-1, 1),
                                 expected_returns, covar,
                                 0.0, 0.0,)
pd.Series(weights).plot(style='.')

# %%
# expected_returns

# %%
portfolio_god = np.dot(stocks.values,np.array(list(weights.values())))
IR_ann = portfolio_god.mean()/portfolio_god.std()*250**0.5
print('IR',IR_ann )
plt.plot(np.exp(portfolio_god.cumsum()))

# %%
trainig_pct = 0.5
n_train = int(trainig_pct*len(stocks.index))

# %%
#Naive
weights_naive = mu.apply(np.sign)/n_stocks
portfolio_naive = np.dot(stocks.values,np.array(list(weights_naive.values)))
IR_ann = portfolio_naive.mean()/portfolio_naive.std()*250**0.5
print('IR',IR_ann )
plt.plot(np.exp(portfolio_naive.cumsum()))
plt.show()
portfolio_naive_oos = portfolio_naive[n_train:]
IR_ann = portfolio_naive_oos.mean()/portfolio_naive_oos.std()*250**0.5
print('IR',IR_ann )
plt.plot(np.exp(portfolio_naive_oos.cumsum()))
plt.show()

# %%
expected_returns = mu
covar = stocks[:n_train].cov()
weights = optimize.minimize_objective(expected_returns.index,
                                 optimize.negative_sharpe,
                                 True,
                                 (-1, 1),
                                 expected_returns, covar,
                                 0.0, 0.0,)
# print(pd.Series(weights))

# %%
# expected_returns

# %%
portfolio_sm = np.dot(stocks.values,np.array(list(weights.values())))
IR_ann = portfolio_sm[n_train:].mean()/portfolio_sm[n_train:].std()*250**0.5
print('IR',IR_ann )
plt.plot(np.exp(portfolio_sm.cumsum())[n_train:])

# %%
print(stocks['portfolio_sampleMean'].mean()/stocks['portfolio_sampleMean'].std()*250**0.5)


np.exp(stocks['portfolio_sampleMean'].cumsum(axis=0))[n_train:].plot()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


x = StandardScaler().fit_transform(stocks[['stock1', 'stock2', 'stock3']])


pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['stock1', 'stock2', 'stock3']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
# import numpy as np
# import pandas as pd
# import scipy.optimize as sco

# def minimize_objective(tickers, objective_function,
#                        market_neutral=True, bounds=(-1, 1), *args):

#     n_assets = len(tickers)

#     if market_neutral:
#         if bounds[0] >= 0:
#             raise ValueError("If market_neutral=True, lower bound must be negative.")
#         constraints = [
#             {"type": "eq", "fun": lambda x: np.sum(x)}]
#     else:
#         constraints = []

#     result = sco.minimize(
#         objective_function,
#         x0=np.array([1/n_assets] * n_assets),
#         args=args,
#         method="SLSQP",
#         bounds=[bounds]*n_assets,
#         constraints=constraints,
#     )
#     weights = result["x"]
#     if not result["success"]:
#         raise ValueError('optimizer did not converge.')
#     return dict(zip(tickers, weights))

# GOD
expected_returns = pd.Series({'stock1': mu_stock1, 'stock2': mu_stock2,'stock3': mu_stock3})
weights = optimize.minimize_objective(expected_returns.index,
                                 optimize.negative_sharpe,
                                 False,
                                 (-1, 1),
                                 expected_returns, covar,
                                 0.0, 0.0,)
print(weights)
stocks['portfolio'] = weights['stock1']*stock1 + weights['stock2']*stock2 + weights['stock3']*stock3
print(stocks['portfolio'].mean()/stocks['portfolio'].std()*250**0.5)
np.exp(stocks['portfolio'].cumsum(axis=0)).plot()

# %%
optimize.negative_sharpe?
